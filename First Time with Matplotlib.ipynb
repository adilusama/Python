# %% [markdown]
# ### Satrting with Matplotlib

# %%
import matplotlib

# %%
import pandas

# %%
from matplotlib import pyplot as plt

# %%
plt.plot ([1,2,3], [1,4,9])
plt.plot ([3,7,9], [2, 4, 6])
plt.legend (['Dataset1', 'Dataset2'])
plt.title('TEST LINE CHART')
plt.show()
plt.savefig('Saved Chart')
